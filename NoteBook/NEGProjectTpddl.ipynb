# %% [markdown]
# <a href="https://colab.research.google.com/github/22922511/tatapower-financial-analysis-dashboard/blob/main/NoteBook/NEGProjectTpddl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## adding columns from 2 row

# %%
dataset=pd.read_csv("/content/Copy of NEG Dashboard-04 May 24 7 may 2024 (002) (1)(List of Schemes) (1).csv",skiprows=2)

# %%
df=dataset

# %%
df.shape
# Out:
# (380, 24)

# %%
df.head(2)
# Out:
#   Approriation Request NO. Zone District Circle DP CIRCLE Scheme Cat  \
# 0           PR/D0513/00097  513      KRR  METRO     METRO   Shifting
# 1           PR/D0513/00099  513      KRR  METRO     METRO   Shifting
#
#   Scheme Categoryold Scheme Category  \
# 0       100% Deposit    100% Deposit
# 1       100% Deposit    100% Deposit
#
#                                 Scheme Description    Status  ...  \
# 0   Shifting of electrical services-Agar N. DSIIDC  Approved  ...
# 1  Shifting of electrical services-Meer V.  DSIIDC  Approved  ...
#
#   Part/Full TECO Amount till 02-May-24 (Rs.)  \
# 0                                41473662.76
# 1                                12497515.04
#
#   Part/Full TECO Amount till 02-May-24(Cr) Net Go Ahead Amount (Rs. In Cr.)  \
# 0                                    4.147                            9.857
# 1                                    1.250                            3.195
#
# ...

# %%
df['DP CIRCLE'].unique()
# Out:
# array(['METRO', 'NRL', 'BWN', 'CITY', 'TOWN', 'RHN-BDL', 'SMB'],
#       dtype=object)

# %%
df['Circle'].unique()
# Out:
# array(['METRO', 'SUC', 'CITY', 'TOWN', 'URBAN'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 24 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Approriation Request NO.                       380 non-null    object
#  1   Zone                                           380 non-null    object
#  2   District                                       380 non-null    object
#  3   Circle                                         380 non-null    object
#  4   DP CIRCLE                                      380 non-null    object
#  5   Scheme Cat                                     380 non-null    object
#  6   Scheme Categoryold                             198 non-null    object
#  7   Scheme Category                                380 non-null    object
#  8   Scheme Description                             380 non-null    object
# ...

# %% [markdown]
# ##Removing Expected Customer Capitalisation Amount (Cr.) and  Targeted Teco Month  columns becasue only 0 non-null values

# %%
df2=df.drop(columns=['Expected Customer Capitalisation Amount (Cr.)','Targeted Teco Month'])

# %%
df2.sample(5)
# Out:
#     Approriation Request NO. Zone District Circle DP CIRCLE Scheme Cat  \
# 7             PR/D0513/00096  513      KRR  METRO     METRO   Shifting
# 33            HR/S0413/00027  413      MDT   TOWN      TOWN        HRB
# 110           HR/S0515/00104  515      MGP  METRO     METRO        HRB
# 280           PR/S0517/00174  517      NRL    SUC       NRL    Sys Imp
# 260           PR/S0519/00218  519      MGP  METRO     METRO    Sys Imp
#
#     Scheme Categoryold Scheme Category  \
# 7         100% Deposit    100% Deposit
# 33                 HRB             HRB
# 110                HRB             HRB
# 280                NaN         Sys Imp
# 260                NaN         Sys Imp
#
#                                     Scheme Description    Status  ...  \
# 7     Shifting of electrical services-Bhagat S. DSIIDC  Approved  ...
# 33   SCH. FOR RELEASING HRB CONN APPLIED NN. 203636...  Approved  ...
# 110  SCHEME FOR RELEASING NEW HRB CONN. NN. 2036416512  Approved  ...
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 22 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Approriation Request NO.                    380 non-null    object
#  1   Zone                                        380 non-null    object
#  2   District                                    380 non-null    object
#  3   Circle                                      380 non-null    object
#  4   DP CIRCLE                                   380 non-null    object
#  5   Scheme Cat                                  380 non-null    object
#  6   Scheme Categoryold                          198 non-null    object
#  7   Scheme Category                             380 non-null    object
#  8   Scheme Description                          380 non-null    object
#  9   Status                                      380 non-null    object
# ...

# %% [markdown]
# ## removing duplicate column 'Scheme Category1' are same 'Scheme Category'

# %%
df2[(df2['Scheme Categoryold']==df2['Scheme Category'] )]

# %%
df3=df2.drop(columns=['Scheme Categoryold',' Budgeted Amount(RS.)','Part/Full TECO Amount till 02-May-24 (Rs.)'])

# %%
df3.sample()
# Out:
#    Approriation Request NO. Zone District Circle DP CIRCLE Scheme Cat  \
# 56           HR/S0522/00375  522      NRL    SUC       NRL        HRB
#
#    Scheme Category                              Scheme Description    Status  \
# 56             HRB  SCHEME FOR RELEASING HRB CONN. NN.- 2036153386  Approved
#
#    Pending/Approval Date Month of Approval   Budgeted Amount(Cr)  \
# 56             4/29/2024            Apr-24                 0.178
#
#     Part/Full TECO Amount till 02-May-24(Cr)  \
# 56                                       0.0
#
#     Net Go Ahead Amount (Rs. In Cr.)        Current Active Status   TECO Date  \
# 56                             0.178  CRTD // DERC BUDR ROW1 INIT  00/01/1900
#
#    Scheme Status Remarks ZPS10 HOG STATUS
# 56          CRTD     NaN  Contracts - PJ7

# %% [markdown]
# ##Performing EDA - Exploratory Data Analysis

# %% [markdown]
# # Finding total number of scheme/project in every circle

# %%
df_circle_pro_cnt=df3.groupby(by='Circle')['Approriation Request NO.'].count().reset_index()
df_circle_pro_cnt=pd.DataFrame(df_circle_zone_cnt)
df_circle_pro_cnt.columns=['Circle','Cnt_of_zone']
df_circle_pro_cnt
# Out:
#   Circle  Cnt_of_zone
# 0   CITY           22
# 1  METRO          104
# 2    SUC          282
# 3   TOWN           34
# 4  URBAN          116

# %% [markdown]
# # Finding total number of zone in every circle

# %%
df_grouped = df3.groupby('Circle')['Zone'].nunique().reset_index()
df_grouped.columns = ['Circle', 'Unique_Zone_Count']
print(df_grouped)
# Out:
#   Circle  Unique_Zone_Count
# 0   CITY                  4
# 1  METRO                  8
# 2    SUC                  8
# 3   TOWN                 12
# 4  URBAN                 12

# %%
plt.bar(df3['Circle'],df3[' Budgeted Amount(Cr)'])
plt.title('budget amount(cr) in each circle')
# Out:
# Text(0.5, 1.0, 'budget amount(cr) in each circle')

# %%
plt.bar(df3['District'],df3[' Budgeted Amount(Cr)'])
plt.title('budget amount(cr) in each district')
# Out:
# Text(0.5, 1.0, 'budget amount(cr) in each district')

# %%
plt.bar(df3['District'],df3['Part/Full TECO Amount till 02-May-24(Cr)'])
plt.title('teco amount(cr) in each district')
# Out:
# Text(0.5, 1.0, 'teco amount(cr) in each district')

# %%
plt.bar(df3['Circle'],df3['Part/Full TECO Amount till 02-May-24(Cr)'])
plt.title('teco amount(cr) in each circle')
# Out:
# Text(0.5, 1.0, 'teco amount(cr) in each circle')

# %%
df3.sample()
# Out:
#    Approriation Request NO. Zone District Circle DP CIRCLE Scheme Cat  \
# 78           HR/S0515/00088  515      MGP  METRO     METRO        HRB
#
#    Scheme Category                                 Scheme Description  \
# 78             HRB  NEW CONNECTION HRB 2035041363 M/S TRISHUL PLAS...
#
#       Status Pending/Approval Date Month of Approval   Budgeted Amount(Cr)  \
# 78  Approved             9/29/2023            Sep-23                 0.119
#
#     Part/Full TECO Amount till 02-May-24(Cr)  \
# 78                                       0.0
#
#     Net Go Ahead Amount (Rs. In Cr.)           Current Active Status  \
# 78                             0.119  REL // CONS DERC BUDV ROW1 WIP
#
#      TECO Date Scheme Status Remarks    ZPS10 HOG STATUS
# 78  00/01/1900           WIP     NaN  HOG : (DP) - Metro

# %%
df3['Month of Approval'] = pd.to_datetime(df3['Month of Approval'], format='%b-%y')
df3 = df3.sort_values('Month of Approval')

# %%
df3.head(2)
# Out:
#     Approriation Request NO.  Zone District Circle DP CIRCLE Scheme Cat  \
# 114           HR/U0532/00027   532      SMB  URBAN       SMB        HRB
# 12            PR/D1303/00029  1303      MTN   CITY      CITY   Shifting
#
#     Scheme Category                                 Scheme Description  \
# 114             HRB  SCHEME FOR RELEASING NEW HCB CONNEC NN.2032960887
# 12     100% Deposit    Shifting of Cable (Pedestrian to ESI Grid wall)
#
#        Status Pending/Approval Date Month of Approval   Budgeted Amount(Cr)  \
# 114  Approved             4/18/2023        2023-04-01                 0.074
# 12   Approved             4/12/2023        2023-04-01                 1.838
#
#      Part/Full TECO Amount till 02-May-24(Cr)  \
# 114                                       0.0
# 12                                        0.0
#
#      Net Go Ahead Amount (Rs. In Cr.)           Current Active Status  \
# 114                             0.074  REL // SRED DERC BUDV ROW1 YTS
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.lineplot(data=df3, x='Month of Approval', y=' Budgeted Amount(Cr)')

plt.title('Budgeted Amount Over Time')
plt.xlabel('Month of Approval')
plt.ylabel('Budgeted Amount (Cr)')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.lineplot(data=df3, x='Month of Approval', y='Part/Full TECO Amount till 02-May-24(Cr)')

plt.title('Budgeted Amount Over Time')
plt.xlabel('Month of Approval')
plt.ylabel('Part/Full TECO Amount till 02-May-24(Cr)')
plt.xticks(rotation=45)
plt.show()
